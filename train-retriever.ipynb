# %%
# !pip uninstall -y tensorflow && pip install tensorflow-cpu
# !pip install datasets typer omegaconf peft sentence-transformers wandb bitsandbytes
# Out:
# Found existing installation: tensorflow 2.18.0
# Uninstalling tensorflow-2.18.0:
#   Successfully uninstalled tensorflow-2.18.0
# Collecting tensorflow-cpu
#   Downloading tensorflow_cpu-2.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-cpu) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-cpu) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow-cpu) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow-cpu) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow-cpu) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-cpu) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow-cpu) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow-cpu) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow-cpu) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-cpu) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow-cpu) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-cpu) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-cpu) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow-cpu) (4.13.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-cpu) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow-cpu) (1.70.0)
# Collecting tensorboard~=2.19.0 (from tensorflow-cpu)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-cpu) (3.5.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-cpu) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-cpu) (3.12.1)
# Collecting ml-dtypes<1.0.0,>=0.5.1 (from tensorflow-cpu)
#   Downloading ml_dtypes-0.5.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow-cpu) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow-cpu) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow-cpu) (14.0.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow-cpu) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow-cpu) (0.14.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<2.2.0,>=1.26.0->tensorflow-cpu) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<2.2.0,>=1.26.0->tensorflow-cpu) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<2.2.0,>=1.26.0->tensorflow-cpu) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<2.2.0,>=1.26.0->tensorflow-cpu) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<2.2.0,>=1.26.0->tensorflow-cpu) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<2.2.0,>=1.26.0->tensorflow-cpu) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow-cpu) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow-cpu) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow-cpu) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow-cpu) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard~=2.19.0->tensorflow-cpu) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard~=2.19.0->tensorflow-cpu) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard~=2.19.0->tensorflow-cpu) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow-cpu) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.2.0,>=1.26.0->tensorflow-cpu) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.2.0,>=1.26.0->tensorflow-cpu) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<2.2.0,>=1.26.0->tensorflow-cpu) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<2.2.0,>=1.26.0->tensorflow-cpu) (2024.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow-cpu) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow-cpu) (2.19.1)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<2.2.0,>=1.26.0->tensorflow-cpu) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-cpu) (0.1.2)
# Downloading tensorflow_cpu-2.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (251.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.8/251.8 MB 7.2 MB/s eta 0:00:00
# Downloading ml_dtypes-0.5.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 96.5 MB/s eta 0:00:00
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 92.4 MB/s eta 0:00:00
# Installing collected packages: ml-dtypes, tensorboard, tensorflow-cpu
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.18.0
#     Uninstalling tensorboard-2.18.0:
#       Successfully uninstalled tensorboard-2.18.0
# Successfully installed ml-dtypes-0.5.1 tensorboard-2.19.0 tensorflow-cpu-2.19.0
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.5.0)
# Requirement already satisfied: typer in /usr/local/lib/python3.11/dist-packages (0.15.1)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.11/dist-packages (2.3.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.14.0)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (0.19.6)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.16)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer) (8.1.8)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from typer) (4.13.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer) (14.0.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from omegaconf) (4.9.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft) (7.0.0)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from peft) (2.5.1+cu124)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from peft) (4.51.1)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from peft) (1.3.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from peft) (0.5.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.15.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb) (4.3.7)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.11.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.21.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb) (1.3.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb) (75.1.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.19.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->datasets) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->datasets) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->datasets) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->datasets) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->datasets) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->datasets) (2.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer) (2.19.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.13.0->peft)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.13.0->peft)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.13.0->peft)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.13.0->peft)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.13.0->peft)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.13.0->peft)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.13.0->peft)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers->peft) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers->peft) (0.21.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->datasets) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->datasets) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->datasets) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->datasets) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->datasets) (2024.2.0)
# Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 23.3 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 10.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 81.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cublas-cu12, fsspec, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bitsandbytes
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.9.90
#     Uninstalling nvidia-curand-cu12-10.3.9.90:
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.12.0 which is incompatible.
# bigframes 1.36.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# pylibcugraph-cu12 24.12.0 requires pylibraft-cu12==24.12.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 24.12.0 requires rmm-cu12==24.12.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed bitsandbytes-0.45.5 fsspec-2024.12.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# %%writefile /kaggle/working/cfg.yaml
# input_dir: "/kaggle/input/data-eedi/exp_output"
# save_dir: "/kaggle/working/"
# best_model_dir: "/kaggle/working/best_models"
# train_biencoder:
#   model_name: "dunzhang/stella_en_1.5B_v5"
#   input_name: "data_kd.csv"
#   output_dir: "output_bi_1.5B"
#   is_lora: true
#   load_in_4bit: false
#   mini_batch_size: 2
#   seed: 42
#   lora_config:
#     r: 48
#     lora_alpha: 96
#   hard_negative_params:
#     range_min: 512
#     num_negatives: 2
#     batch_size: 32
#   train_args:
#     num_train_epochs: 1.0
#     per_device_train_batch_size: 16
#     per_device_eval_batch_size: 4
#     learning_rate: 0.001
#     warmup_steps: 0
#     eval_strategy: steps
#     save_only_model: true
#     eval_steps: 10
#     metric_for_best_model: val_cosine_recall@100
#     load_best_model_at_end: true
#     greater_is_better: true
#     save_strategy: steps
#     save_steps: 10
#     lr_scheduler_type: "cosine"
#     save_total_limit: 1
#     logging_steps: 1
#     report_to: wandb
#     bf16: true
# Out:
# Writing /kaggle/working/cfg.yaml

# %%
# %%writefile /kaggle/working/train_retriever.py
from collections import defaultdict
from pathlib import Path
from typing import DefaultDict, Dict, Set

import pandas as pd
import typer
from datasets import Dataset
from omegaconf import OmegaConf
from peft import LoraConfig, TaskType, get_peft_model

from sentence_transformers import (
    SentenceTransformer,
    SentenceTransformerTrainer,
    SentenceTransformerTrainingArguments,
    losses,
    models
)
from sentence_transformers.evaluation import InformationRetrievalEvaluator
from sentence_transformers.training_args import BatchSamplers
from sentence_transformers.util import mine_hard_negatives
from transformers import set_seed,BitsAndBytesConfig
from transformers.training_args import ParallelMode

import torch
import torch.distributed as dist

import json
import wandb
import typer
# Template for formatting the prompt
PROMPT_FORMAT: str = """Subject: {SubjectName}
Construct: {ConstructName}
Question: {QuestionText}
CorrectAnswer: {Correct}
IncorrectAnswer: {Answer}
IncorrectReason: {kd}"""


def create_val(df: pd.DataFrame, mapping: pd.DataFrame) -> pd.DataFrame:
    """
    Create validation dataset by merging dataframe with mapping and adding labels.

    Args:
        df: Input DataFrame containing the base data
        mapping: DataFrame containing misconception mapping information

    Returns:
        DataFrame with processed validation data
    """
    df = df.merge(mapping, how="cross")
    df["label"] = 0
    df.loc[df["MisconceptionId_x"] == df["MisconceptionId_y"], "label"] = 1
    target_cols = ["prompt", "MisconceptionName_y", "label"]
    df = df[target_cols].rename(columns={"MisconceptionName_y": "MisconceptionName"})
    return df


def create_evaluator(df: pd.DataFrame, name: str = "train") -> InformationRetrievalEvaluator:
    """
    Create an evaluator for information retrieval tasks.

    Args:
        df: DataFrame containing prompts, misconception names, and labels
        name: Name identifier for the evaluator

    Returns:
        Configured InformationRetrievalEvaluator object
    """
    relevant_docs: DefaultDict[str, Set[str]] = defaultdict(set)
    queries: Dict[str, str] = {str(k): v for k, v in enumerate(df["prompt"].unique())}
    corpus: Dict[str, str] = {str(k): v for k, v in enumerate(df["MisconceptionName"].unique())}

    # Create reverse mappings for efficient lookup
    qid_dict: Dict[str, str] = {v: k for k, v in queries.items()}
    cid_dict: Dict[str, str] = {v: k for k, v in corpus.items()}

    # Build relevant documents mapping
    for prompt, g in df.groupby("prompt"):
        for mis_name, label in g[["MisconceptionName", "label"]].values:
            if label == 1:
                qid = qid_dict[str(prompt)]
                cid = cid_dict[mis_name]
                relevant_docs[qid].add(cid)

    return InformationRetrievalEvaluator(
        queries=queries,
        corpus=corpus,
        relevant_docs=relevant_docs,
        name=name,
        map_at_k=[25],
        mrr_at_k=[25],
        precision_recall_at_k=[50, 100, 150, 200],
        ndcg_at_k=[25],
        accuracy_at_k=[25],
    )


def main(
    fold: int = typer.Option(..., help="Fold number for cross-validation"),
    config= "/kaggle/working/cfg.yaml",
) -> None:
    """
    Main training function for the bi-encoder model.

    Args:
        fold: Cross-validation fold number
        config: Path to configuration file
    """
    # Load configuration
    cfg = OmegaConf.load(config)
    params = cfg.train_biencoder
    set_seed(params.seed)

    # Load and prepare data
    df = pd.read_csv(Path(cfg.input_dir) / params.input_name)
    mapping = pd.read_csv("/kaggle/input/eedi-mining-misconceptions-in-mathematics/misconception_mapping.csv")
    df["prompt"] = df.apply(lambda x: PROMPT_FORMAT.format(**x), axis=1)

    # Split data into train and validation sets
    train_df = df.loc[df.fold != fold].copy()
    val_df = df.loc[(df.fold == fold) & (df.original)].copy()
    val_df = create_val(val_df, mapping)

    # Create dataset for training
    train_dset = Dataset.from_dict(
        {
            "anchor": train_df["prompt"].tolist(),
            "positive": train_df["MisconceptionName"].tolist(),
        }
    )

    # Setup paths and wandb
    name = f"fold_{fold}"
    output_dir = str(Path(cfg.save_dir) / params.output_dir / name)
    best_model_path = str(Path(cfg.best_model_dir) / params.output_dir / name)
    wandb.login(key="ccd07261eef86e04beb9d6f9e459d8995bdc4b16")
    wandb.init(project="eedi-biencoder", name=f"{name}_{params.model_name.split('/')[-1]}")

    # Initialize model
    model = SentenceTransformer(
        params.model_name,
        trust_remote_code=True,
        model_kwargs={"load_in_4bit": params.load_in_4bit,"torch_dtype":torch.bfloat16},
    )
    # Perform hard negative mining
    train_dset = mine_hard_negatives(
        train_dset,
        model,
        **params["hard_negative_params"],
    )
    # train_dset.save_to_disk("/kaggle/working/train_dset_hard_negatives")
    # train_dset = Dataset.load_from_disk("/kaggle/working/train_dset_hard_negatives")
    # Add LoRA adapter if specified
    if params.is_lora:
        peft_config = LoraConfig(
            task_type=TaskType.FEATURE_EXTRACTION,
            inference_mode=False,
            target_modules="all-linear",
            lora_dropout=0.01,
            **params["lora_config"],
        )
        # Apply LoRA BEFORE dispatching
        model[0].auto_model = get_peft_model(model[0].auto_model, peft_config)
        model[0].auto_model.print_trainable_parameters()
    
        # # Dispatch model AFTER applying LoRA
        # try:
        #     device_map_path = "/kaggle/working/device_map.json"
        #     with open(device_map_path, "r") as f:
        #         device_map = json.load(f)
        #         device_map = {k: str(v) for k, v in device_map.items()}
        #     model[0].auto_model = dispatch_model(model[0].auto_model, device_map=device_map)
        #     print("✅ LoRA model dispatched to multiple GPUs.")
        # except Exception as e:
        #     print("⚠️ Failed to dispatch LoRA model:", e)
    # Setup loss function and evaluator
    loss = losses.CachedMultipleNegativesRankingLoss(
        model, mini_batch_size=params.mini_batch_size, show_progress_bar=True
    )
    val_evaluator = create_evaluator(val_df, name="val")
    
    # Configure training arguments
    args = SentenceTransformerTrainingArguments(
        **params.train_args,
        output_dir=output_dir,
        batch_sampler=BatchSamplers.NO_DUPLICATES,
    )
    # Initialize and run trainer
    trainer = SentenceTransformerTrainer(
        args=args,
        model=model,
        train_dataset=train_dset,
        loss=loss,
        evaluator=val_evaluator,
    )
    trainer.train()
    trainer.save_model(best_model_path)

if __name__ == "__main__":
    typer.run(main)
# Out:
# Writing /kaggle/working/train_retriever.py

# %%
# !python /kaggle/working/train_retriever.py --fold 4
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: cong-nh225476 (cong-nh225476-hanoi-university-of-science-and-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Tracking run with wandb version 0.19.6
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250520_121200-v6x3uwb9
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run fold_4_stella_en_1.5B_v5
# wandb: ⭐️ View project at https://wandb.ai/cong-nh225476-hanoi-university-of-science-and-technology/eedi-biencoder
# wandb: 🚀 View run at https://wandb.ai/cong-nh225476-hanoi-university-of-science-and-technology/eedi-biencoder/runs/v6x3uwb9
# modules.json: 100%|█████████████████████████████| 316/316 [00:00<00:00, 877kB/s]
# config_sentence_transformers.json: 100%|███████| 397/397 [00:00<00:00, 1.14MB/s]
# README.md: 100%|█████████████████████████████| 169k/169k [00:00<00:00, 5.53MB/s]
# sentence_bert_config.json: 100%|██████████████| 51.0/51.0 [00:00<00:00, 135kB/s]
# config.json: 100%|█████████████████████████████| 844/844 [00:00<00:00, 1.92MB/s]
# modeling_qwen.py: 100%|████████████████████| 65.3k/65.3k [00:00<00:00, 41.3MB/s]
# A new version of the following files was downloaded from https://huggingface.co/dunzhang/stella_en_1.5B_v5:
# - modeling_qwen.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors: 100%|████████████████████| 6.17G/6.17G [00:32<00:00, 189MB/s]
# tokenizer_config.json: 100%|███████████████| 1.31k/1.31k [00:00<00:00, 3.07MB/s]
# tokenization_qwen.py: 100%|████████████████| 10.8k/10.8k [00:00<00:00, 24.0MB/s]
# A new version of the following files was downloaded from https://huggingface.co/dunzhang/stella_en_1.5B_v5:
# - tokenization_qwen.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# vocab.json: 100%|██████████████████████████| 2.78M/2.78M [00:00<00:00, 9.99MB/s]
# merges.txt: 100%|██████████████████████████| 1.67M/1.67M [00:00<00:00, 13.5MB/s]
# tokenizer.json: 100%|██████████████████████| 7.03M/7.03M [00:00<00:00, 27.0MB/s]
# added_tokens.json: 100%|██████████████████████| 80.0/80.0 [00:00<00:00, 194kB/s]
# special_tokens_map.json: 100%|██████████████████| 370/370 [00:00<00:00, 841kB/s]
# config.json: 100%|██████████████████████████████| 289/289 [00:00<00:00, 773kB/s]
# config.json: 100%|██████████████████████████████| 122/122 [00:00<00:00, 327kB/s]
# pytorch_model.bin: 100%|███████████████████| 6.30M/6.30M [00:00<00:00, 69.9MB/s]
# model.safetensors: 100%|███████████████████| 6.30M/6.30M [00:00<00:00, 67.9MB/s]
# Setting range_max to 516 based on the provided parameters.
# Found 4277 unique queries out of 4281 total queries.
# Found an average of 1.001 positives per query.
# Batches: 100%|██████████████████████████████████| 66/66 [00:24<00:00,  2.72it/s]
# Batches: 100%|████████████████████████████████| 134/134 [14:26<00:00,  6.47s/it]
# Metric       Positive       Negative     Difference
# Count           4,281          8,562
# Mean           0.6098         0.4388         0.1711
# Median         0.6185         0.4401         0.1779
# Std            0.0798         0.0284         0.0875
# Min            0.3317         0.2925        -0.1228
# 25%            0.5613         0.4203         0.1186
# 50%            0.6185         0.4401         0.1779
# 75%            0.6674         0.4592         0.2352
# Max            0.8263         0.5199         0.4170
# trainable params: 55,394,304 || all params: 1,598,663,168 || trainable%: 3.4650
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
#   0%|                                                   | 0/536 [00:00<?, ?it/s]
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  2.18it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:01<00:03,  1.81it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  1.71it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:02<00:02,  1.67it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  1.65it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:03<00:01,  1.63it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:04<00:00,  1.62it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:04<00:00,  1.66it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:02,  3.02it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  3.88it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.27it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.48it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.60it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.68it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.74it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.50it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:01,  4.56it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  4.44it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.41it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.39it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.38it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.37it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.37it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.38it/s]
#
# Preparing caches: 100%|██████████████████████████| 8/8 [00:00<00:00, 120.87it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:01<00:08,  1.16s/it]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:02<00:07,  1.25s/it]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:03<00:06,  1.27s/it]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:05<00:05,  1.28s/it]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:06<00:03,  1.29s/it]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:07<00:02,  1.29s/it]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:08<00:01,  1.30s/it]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:10<00:00,  1.29s/it]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  1.95it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.14it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.21it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.25it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.27it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.28it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.29it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.25it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  2.19it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.17it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.17it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.17it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.17it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.17it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.17it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.17it/s]
# {'loss': 0.7341, 'grad_norm': 2.6579177379608154, 'learning_rate': 0.001, 'epoch': 0.0}
#   0%|                                         | 1/536 [00:26<3:54:33, 26.31s/it]
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  2.29it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:01<00:03,  1.82it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  1.71it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:02<00:02,  1.66it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  1.64it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:03<00:01,  1.62it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:04<00:00,  1.61it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:04<00:00,  1.66it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:02,  3.03it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  3.92it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.32it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.55it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.68it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.76it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.82it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.57it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:01,  4.98it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  4.93it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.92it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.91it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.90it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.90it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.90it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.90it/s]
#
# Preparing caches: 100%|██████████████████████████| 8/8 [00:00<00:00, 520.70it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:01<00:08,  1.17s/it]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:02<00:07,  1.27s/it]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:03<00:06,  1.29s/it]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:05<00:05,  1.30s/it]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:06<00:03,  1.31s/it]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:07<00:02,  1.31s/it]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:09<00:01,  1.31s/it]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:10<00:00,  1.30s/it]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  1.95it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.16it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.24it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.28it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.30it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.31it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.32it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.28it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:02,  2.34it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.33it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.33it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.33it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.33it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.33it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.32it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.32it/s]
# {'loss': 1.1246, 'grad_norm': 3.7170236110687256, 'learning_rate': 0.0009999914116658895, 'epoch': 0.0}
#   0%|▏                                        | 2/536 [00:52<3:51:17, 25.99s/it]
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  2.16it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:01<00:03,  1.72it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:03,  1.61it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:02<00:02,  1.57it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:03<00:01,  1.55it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:03<00:01,  1.53it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:04<00:00,  1.52it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:05<00:00,  1.56it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:02,  2.95it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  3.86it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.28it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.51it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.65it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.74it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.80it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.54it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:01,  5.00it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  4.95it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.94it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.94it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.93it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.92it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.93it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.92it/s]
#
# Preparing caches: 100%|██████████████████████████| 8/8 [00:00<00:00, 464.86it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:01<00:08,  1.23s/it]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:02<00:08,  1.33s/it]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:04<00:06,  1.36s/it]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:05<00:05,  1.37s/it]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:06<00:04,  1.38s/it]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:08<00:02,  1.38s/it]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:09<00:01,  1.38s/it]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:10<00:00,  1.37s/it]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  1.93it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.15it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.22it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.26it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.29it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.30it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.31it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.27it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:02,  2.35it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.34it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.34it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.34it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.34it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.33it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:02<00:00,  2.33it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.33it/s]
# {'loss': 1.1668, 'grad_norm': 5.750168323516846, 'learning_rate': 0.0009999656469585956, 'epoch': 0.01}
#   1%|▏                                        | 3/536 [01:18<3:53:18, 26.26s/it]
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  2.10it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:01<00:03,  1.67it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:03,  1.56it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:02<00:02,  1.52it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:03<00:02,  1.50it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:03<00:01,  1.48it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:04<00:00,  1.48it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:05<00:00,  1.52it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:02,  2.88it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  3.81it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.25it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.50it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.64it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.73it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.80it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.52it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:01,  4.93it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  4.88it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.86it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.85it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.85it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.85it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.84it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.85it/s]
#
# Preparing caches: 100%|██████████████████████████| 8/8 [00:00<00:00, 573.66it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:01<00:08,  1.28s/it]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:02<00:08,  1.39s/it]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:04<00:07,  1.42s/it]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:05<00:05,  1.43s/it]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:07<00:04,  1.43s/it]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:08<00:02,  1.44s/it]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:09<00:01,  1.44s/it]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:11<00:00,  1.43s/it]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  1.91it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.14it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.23it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.27it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.29it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.31it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.32it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.27it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  2.32it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.31it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.31it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.31it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.30it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.31it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.31it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.31it/s]
# {'loss': 1.2752, 'grad_norm': 3.821110486984253, 'learning_rate': 0.0009999227067632223, 'epoch': 0.01}
#   1%|▎                                        | 4/536 [01:45<3:56:27, 26.67s/it]
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  2.30it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:01<00:03,  1.83it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  1.72it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:02<00:02,  1.67it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  1.64it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:03<00:01,  1.63it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:04<00:00,  1.62it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:04<00:00,  1.66it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:02,  3.02it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  3.89it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.28it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.49it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.62it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.70it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.76it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.52it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:01,  4.93it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  4.88it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.86it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.85it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.85it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.84it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.84it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.85it/s]
#
# Preparing caches: 100%|██████████████████████████| 8/8 [00:00<00:00, 543.30it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:01<00:08,  1.16s/it]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:02<00:07,  1.25s/it]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:03<00:06,  1.28s/it]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:05<00:05,  1.29s/it]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:06<00:03,  1.29s/it]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:07<00:02,  1.30s/it]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:08<00:01,  1.30s/it]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:10<00:00,  1.29s/it]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  1.95it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.15it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.22it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.26it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.28it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.29it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.30it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.26it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  2.32it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.31it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.31it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.31it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.31it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.31it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.30it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.30it/s]
# {'loss': 1.2428, 'grad_norm': 3.329664468765259, 'learning_rate': 0.000999862592554908, 'epoch': 0.01}
#   1%|▍                                        | 5/536 [02:11<3:52:57, 26.32s/it]
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  2.08it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:01<00:03,  1.65it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:03,  1.55it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:02<00:02,  1.51it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:03<00:02,  1.49it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:03<00:01,  1.47it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:04<00:00,  1.46it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:05<00:00,  1.50it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:02,  2.86it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  3.80it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.25it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.49it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.64it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.74it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.80it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.52it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:01,  4.98it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  4.93it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.92it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.91it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.91it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.90it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.90it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.91it/s]
#
# Preparing caches: 100%|██████████████████████████| 8/8 [00:00<00:00, 586.43it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:01<00:09,  1.31s/it]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:02<00:08,  1.42s/it]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:04<00:07,  1.44s/it]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:05<00:05,  1.46s/it]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:07<00:04,  1.46s/it]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:08<00:02,  1.47s/it]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:10<00:01,  1.47s/it]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:11<00:00,  1.46s/it]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  1.89it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.13it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.22it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.27it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.29it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.31it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.31it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.27it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:02,  2.34it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.33it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.33it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.33it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.33it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.33it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.32it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.32it/s]
# {'loss': 0.8722, 'grad_norm': 2.2479734420776367, 'learning_rate': 0.0009997853063987768, 'epoch': 0.01}
#   1%|▍                                        | 6/536 [02:39<3:56:06, 26.73s/it]
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  2.14it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:01<00:03,  1.71it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:03,  1.60it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:02<00:02,  1.55it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:03<00:01,  1.53it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:03<00:01,  1.52it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:04<00:00,  1.51it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:05<00:00,  1.55it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:02,  2.91it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  3.83it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.27it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.50it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.65it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.74it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.80it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.53it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:01,  4.58it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  4.45it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.41it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.39it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.38it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.37it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.37it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.38it/s]
#
# Preparing caches: 100%|██████████████████████████| 8/8 [00:00<00:00, 599.53it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:01<00:08,  1.26s/it]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:02<00:08,  1.36s/it]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:04<00:06,  1.38s/it]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:05<00:05,  1.40s/it]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:06<00:04,  1.40s/it]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:08<00:02,  1.40s/it]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:09<00:01,  1.41s/it]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:11<00:00,  1.40s/it]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  1.92it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.14it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.23it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.27it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.29it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.31it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.32it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.27it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  2.19it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.17it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.17it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.17it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.17it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.16it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.16it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.17it/s]
# {'loss': 0.9877, 'grad_norm': 5.086812973022461, 'learning_rate': 0.000999690850949866, 'epoch': 0.01}
#   1%|▌                                        | 7/536 [03:06<3:57:20, 26.92s/it]
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  2.08it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:01<00:03,  1.65it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:03,  1.55it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:02<00:02,  1.51it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:03<00:02,  1.49it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:03<00:01,  1.47it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:04<00:00,  1.46it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:05<00:00,  1.50it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:02,  2.86it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  3.79it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.24it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.48it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.63it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.73it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.79it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.51it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:01,  4.56it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  4.43it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.39it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.38it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.37it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.36it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.36it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.37it/s]
#
# Preparing caches: 100%|██████████████████████████| 8/8 [00:00<00:00, 595.72it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:01<00:09,  1.31s/it]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:02<00:08,  1.42s/it]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:04<00:07,  1.44s/it]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:05<00:05,  1.46s/it]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:07<00:04,  1.46s/it]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:08<00:02,  1.47s/it]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:10<00:01,  1.47s/it]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:11<00:00,  1.46s/it]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  1.89it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.12it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.21it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.26it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.28it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.30it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.31it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.26it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  2.17it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.16it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.16it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.16it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.15it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.15it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.15it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.15it/s]
# {'loss': 0.3914, 'grad_norm': 2.4712510108947754, 'learning_rate': 0.0009995792294530356, 'epoch': 0.01}
#   1%|▌                                        | 8/536 [03:34<3:59:58, 27.27s/it]
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  2.08it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:01<00:03,  1.65it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:03,  1.55it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:02<00:02,  1.51it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:03<00:02,  1.48it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:03<00:01,  1.47it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:04<00:00,  1.46it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:05<00:00,  1.50it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:02,  2.86it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  3.80it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.24it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.49it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.64it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.73it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.80it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.52it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:01,  5.00it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  4.96it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.95it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.94it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.94it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.94it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.94it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.94it/s]
#
# Preparing caches: 100%|██████████████████████████| 8/8 [00:00<00:00, 598.03it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:01<00:09,  1.31s/it]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:02<00:08,  1.42s/it]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:04<00:07,  1.44s/it]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:05<00:05,  1.46s/it]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:07<00:04,  1.46s/it]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:08<00:02,  1.47s/it]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:10<00:01,  1.47s/it]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:11<00:00,  1.46s/it]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  1.88it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.13it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.22it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.26it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.29it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.30it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.31it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.27it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:02,  2.35it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.34it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.34it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.34it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.34it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.34it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:02<00:00,  2.34it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.34it/s]
# {'loss': 1.6333, 'grad_norm': 6.780029773712158, 'learning_rate': 0.0009994504457428556, 'epoch': 0.02}
#   2%|▋                                        | 9/536 [04:02<4:00:07, 27.34s/it]
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  2.08it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:01<00:03,  1.65it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:03,  1.55it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:02<00:02,  1.51it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:03<00:02,  1.49it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:03<00:01,  1.47it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:04<00:00,  1.46it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:05<00:00,  1.50it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:02,  2.86it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  3.80it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.24it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.49it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.64it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.74it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.80it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.52it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:01,  5.00it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  4.96it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.93it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.94it/s]
# ...
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.16it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.16it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.16it/s]
# {'loss': 0.2637, 'grad_norm': 2.834765911102295, 'learning_rate': 2.1469360122317038e-07, 'epoch': 0.99}
#  99%|██████████████████████████████████████▋| 532/536 [7:29:31<05:13, 78.32s/it]
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  2.08it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:01<00:03,  1.66it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:03,  1.56it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:02<00:02,  1.51it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:03<00:02,  1.49it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:03<00:01,  1.48it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:04<00:00,  1.47it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:05<00:00,  1.51it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:02,  2.87it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  3.80it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.24it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.49it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.63it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.73it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.79it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.51it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:01,  4.97it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  4.91it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.88it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.88it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.87it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.87it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.86it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.87it/s]
#
# Preparing caches: 100%|██████████████████████████| 8/8 [00:00<00:00, 507.63it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:01<00:09,  1.30s/it]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:02<00:08,  1.42s/it]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:04<00:07,  1.44s/it]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:05<00:05,  1.45s/it]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:07<00:04,  1.46s/it]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:08<00:02,  1.46s/it]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:10<00:01,  1.47s/it]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:11<00:00,  1.45s/it]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  1.89it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.13it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.22it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.26it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.28it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.30it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.31it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.26it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:02,  2.33it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.32it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.32it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.32it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.31it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.31it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.31it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.31it/s]
# {'loss': 0.6997, 'grad_norm': 4.468409538269043, 'learning_rate': 1.374074450920526e-07, 'epoch': 0.99}
#  99%|██████████████████████████████████████▊| 533/536 [7:29:59<03:09, 63.08s/it]
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  2.30it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:01<00:03,  1.83it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  1.71it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:02<00:02,  1.67it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  1.64it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:03<00:01,  1.63it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:04<00:00,  1.62it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:04<00:00,  1.66it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:02,  3.04it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  3.92it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.32it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.54it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.66it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.75it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.81it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.56it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:01,  5.02it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  4.96it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.94it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.94it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.93it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.93it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.93it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.93it/s]
#
# Preparing caches: 100%|██████████████████████████| 8/8 [00:00<00:00, 505.95it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:01<00:08,  1.16s/it]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:02<00:07,  1.26s/it]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:03<00:06,  1.28s/it]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:05<00:05,  1.29s/it]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:06<00:03,  1.29s/it]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:07<00:02,  1.30s/it]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:09<00:01,  1.30s/it]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:10<00:00,  1.29s/it]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  1.96it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.17it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.24it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.28it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.30it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.31it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.32it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.28it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:02,  2.36it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.34it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.34it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.34it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.34it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.33it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:02<00:00,  2.33it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.33it/s]
# {'loss': 0.3827, 'grad_norm': 5.011250019073486, 'learning_rate': 7.729323677790889e-08, 'epoch': 1.0}
# 100%|██████████████████████████████████████▊| 534/536 [7:30:24<01:43, 51.84s/it]
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  2.09it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:01<00:03,  1.66it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:03,  1.56it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:02<00:02,  1.52it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:03<00:02,  1.49it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:03<00:01,  1.48it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:04<00:00,  1.47it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:05<00:00,  1.51it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:02,  2.85it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  3.75it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.18it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.41it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.55it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.64it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.69it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.43it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:01,  4.90it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:01,  4.86it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:00<00:01,  4.85it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:00<00:00,  4.85it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:01<00:00,  4.84it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:01<00:00,  4.84it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:01<00:00,  4.84it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:01<00:00,  4.84it/s]
#
# Preparing caches: 100%|██████████████████████████| 8/8 [00:00<00:00, 533.70it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:01<00:08,  1.29s/it]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:02<00:08,  1.39s/it]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:04<00:07,  1.42s/it]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:05<00:05,  1.43s/it]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:07<00:04,  1.44s/it]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:08<00:02,  1.44s/it]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:09<00:01,  1.44s/it]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:11<00:00,  1.43s/it]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  1.88it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.11it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.19it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.23it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.26it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.27it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.28it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.24it/s]
#
# Embed mini-batches:   0%|                                 | 0/8 [00:00<?, ?it/s]
# Embed mini-batches:  12%|███▏                     | 1/8 [00:00<00:03,  2.32it/s]
# Embed mini-batches:  25%|██████▎                  | 2/8 [00:00<00:02,  2.31it/s]
# Embed mini-batches:  38%|█████████▍               | 3/8 [00:01<00:02,  2.31it/s]
# Embed mini-batches:  50%|████████████▌            | 4/8 [00:01<00:01,  2.31it/s]
# Embed mini-batches:  62%|███████████████▋         | 5/8 [00:02<00:01,  2.31it/s]
# Embed mini-batches:  75%|██████████████████▊      | 6/8 [00:02<00:00,  2.31it/s]
# Embed mini-batches:  88%|█████████████████████▉   | 7/8 [00:03<00:00,  2.30it/s]
# Embed mini-batches: 100%|█████████████████████████| 8/8 [00:03<00:00,  2.31it/s]
# {'loss': 0.4079, 'grad_norm': 4.309621810913086, 'learning_rate': 3.4353041404477926e-08, 'epoch': 1.0}
# 100%|██████████████████████████████████████▉| 535/536 [7:30:52<00:44, 44.51s/it]
# Embed mini-batches:   0%|                                 | 0/1 [00:00<?, ?it/s]
# Embed mini-batches: 100%|█████████████████████████| 1/1 [00:00<00:00,  2.68it/s]
#
# Embed mini-batches:   0%|                                 | 0/1 [00:00<?, ?it/s]
# Embed mini-batches: 100%|█████████████████████████| 1/1 [00:00<00:00,  3.31it/s]
#
# Embed mini-batches:   0%|                                 | 0/1 [00:00<?, ?it/s]
# Embed mini-batches: 100%|█████████████████████████| 1/1 [00:00<00:00,  4.95it/s]
#
# Preparing caches: 100%|██████████████████████████| 1/1 [00:00<00:00, 205.99it/s]
#
# Embed mini-batches:   0%|                                 | 0/1 [00:00<?, ?it/s]
# Embed mini-batches: 100%|█████████████████████████| 1/1 [00:01<00:00,  1.00s/it]
#
# Embed mini-batches:   0%|                                 | 0/1 [00:00<?, ?it/s]
# Embed mini-batches: 100%|█████████████████████████| 1/1 [00:00<00:00,  1.96it/s]
#
# Embed mini-batches:   0%|                                 | 0/1 [00:00<?, ?it/s]
# Embed mini-batches: 100%|█████████████████████████| 1/1 [00:00<00:00,  2.34it/s]
# {'loss': 0.0003, 'grad_norm': 0.014146110974252224, 'learning_rate': 8.588334110604113e-09, 'epoch': 1.0}
# {'train_runtime': 27056.664, 'train_samples_per_second': 0.316, 'train_steps_per_second': 0.02, 'train_loss': 1.0359480028662855, 'epoch': 1.0}
# 100%|███████████████████████████████████████| 536/536 [7:30:56<00:00, 50.48s/it]
# wandb:
# wandb: 🚀 View run fold_4_stella_en_1.5B_v5 at: https://wandb.ai/cong-nh225476-hanoi-university-of-science-and-technology/eedi-biencoder/runs/v6x3uwb9
# wandb: Find logs at: wandb/run-20250520_121200-v6x3uwb9/logs
